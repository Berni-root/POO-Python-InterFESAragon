# %% [markdown]
# <a href="https://colab.research.google.com/github/Berni-root/POO-Python-InterFESAragon/blob/main/Sesion0202LecturaDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prepocesamiento de Datos con Python
# ##FES Aragón
# ###ICO
# ####BERNABÉ HERNÁNDEZ CISNEROS

# %%
import pandas as pd
from pandas.io.json import read_json

# %%
! dir C:/Users/sacmex5242/Downloads/datos
# Out:
# dir: cannot access 'C:/Users/sacmex5242/Downloads/datos': No such file or directory

# %%
! cat /content/clientes.csv
# Out:
# ident,nombre,primer_apellido,suc_origen
# 19232,Adriana,Sánchez,CDMX01
# 19233,Marcos,García,CDMX02
# 19234,Rubén,Rincón,CDMX02
# 19235,Samuel,Oliva,CDMX01
# 19236,Martha,Martínez,CDMX03

# %%
df_clientes = pd.read_csv("/content/clientes.csv")
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ident            5 non-null      int64
#  1   nombre           5 non-null      object
#  2   primer_apellido  5 non-null      object
#  3   suc_origen       5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df_clientes
# Out:
#    ident   nombre primer_apellido suc_origen
# 0  19232  Adriana         Sánchez     CDMX01
# 1  19233   Marcos          García     CDMX02
# 2  19234    Rubén          Rincón     CDMX02
# 3  19235   Samuel           Oliva     CDMX01
# 4  19236   Martha        Martínez     CDMX03

# %%
df_facturas = pd.read_csv("/content/facturas.csv", sep='|')
df_facturas
# Out:
#    folio sucursal     monto                fecha  cliente
# 0  15234   CDMX01   1420.00  2019-03-11 17:24:00    19234
# 1  15235    MTY01   1532.00  2019-03-24 14:46:00    19232
# 2  15236   CDMX02    890.00  2019-03-25 17:58:00    19235
# 3  15237   CDMX02   1300.00  2019-03-27 13:11:00    19233
# 4  15238    MTY01   3121.47  2019-03-31 10:25:00    19236
# 5  15239    GDL01   1100.50  2019-04-01 18:32:00    19237
# 6  15240   CDMX02  12230.00  2019-04-03 11:43:00    19232
# 7  15241    MTY01    230.85  2019-04-04 16:55:00    19233
# 8  15242    GDL01   1569.00  2019-04-05 12:59:00    19232
# 9  15243    GDL01   2569.00  2019-05-05 12:59:00    19232

# %%
df_players = pd.read_csv("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/jugadores.csv")
df_players # Lectura desde una petición web https
# Out:
#                  Name Team        Position  Height(inches)  Weight(pounds)  \
# 0       Adam_Donachie  BAL         Catcher              74             180
# 1           Paul_Bako  BAL         Catcher              74             215
# 2     Ramon_Hernandez  BAL         Catcher              72             210
# 3        Kevin_Millar  BAL   First_Baseman              72             210
# 4         Chris_Gomez  BAL   First_Baseman              73             188
# ...               ...  ...             ...             ...             ...
# 1029    Brad_Thompson  STL  Relief_Pitcher              73             190
# 1030    Tyler_Johnson  STL  Relief_Pitcher              74             180
# 1031   Chris_Narveson  STL  Relief_Pitcher              75             205
# 1032    Randy_Keisler  STL  Relief_Pitcher              75             190
# 1033      Josh_Kinney  STL  Relief_Pitcher              73             195
#
#         Age
# 0     22.99
# 1     34.69
# 2     30.78
# 3     35.43
# ...

# %%
df_players.head() # sin parámetro trae 5 elementos
# Out:
#               Name Team       Position  Height(inches)  Weight(pounds)    Age
# 0    Adam_Donachie  BAL        Catcher              74             180  22.99
# 1        Paul_Bako  BAL        Catcher              74             215  34.69
# 2  Ramon_Hernandez  BAL        Catcher              72             210  30.78
# 3     Kevin_Millar  BAL  First_Baseman              72             210  35.43
# 4      Chris_Gomez  BAL  First_Baseman              73             188  35.71

# %%
df_players.head(10) # con parámetro trae los indicados
# Out:
#               Name Team        Position  Height(inches)  Weight(pounds)    Age
# 0    Adam_Donachie  BAL         Catcher              74             180  22.99
# 1        Paul_Bako  BAL         Catcher              74             215  34.69
# 2  Ramon_Hernandez  BAL         Catcher              72             210  30.78
# 3     Kevin_Millar  BAL   First_Baseman              72             210  35.43
# 4      Chris_Gomez  BAL   First_Baseman              73             188  35.71
# 5    Brian_Roberts  BAL  Second_Baseman              69             176  29.39
# 6    Miguel_Tejada  BAL       Shortstop              69             209  30.77
# 7      Melvin_Mora  BAL   Third_Baseman              71             200  35.07
# 8      Aubrey_Huff  BAL   Third_Baseman              76             231  30.19
# 9       Adam_Stern  BAL      Outfielder              71             180  27.05

# %%
df_players.tail() # trae los ultimos
# Out:
#                 Name Team        Position  Height(inches)  Weight(pounds)  \
# 1029   Brad_Thompson  STL  Relief_Pitcher              73             190
# 1030   Tyler_Johnson  STL  Relief_Pitcher              74             180
# 1031  Chris_Narveson  STL  Relief_Pitcher              75             205
# 1032   Randy_Keisler  STL  Relief_Pitcher              75             190
# 1033     Josh_Kinney  STL  Relief_Pitcher              73             195
#
#         Age
# 1029  25.08
# 1030  25.73
# 1031  25.19
# 1032  31.01
# 1033  27.92

# %%
df_players.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height(inches)', 'Weight(pounds)', 'Age'], dtype='object')

# %%
#Renombrar columnas de DF
columnas = ['Nombre','Equipo','Posicion','Altura','Peso','Edad']
df_jugadores = pd.read_csv(
    "https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/jugadores.csv",
                         names=columnas, header=None, skiprows=1)

# %%
df_jugadores
# Out:
#                Nombre Equipo        Posicion  Altura  Peso   Edad
# 0       Adam_Donachie    BAL         Catcher      74   180  22.99
# 1           Paul_Bako    BAL         Catcher      74   215  34.69
# 2     Ramon_Hernandez    BAL         Catcher      72   210  30.78
# 3        Kevin_Millar    BAL   First_Baseman      72   210  35.43
# 4         Chris_Gomez    BAL   First_Baseman      73   188  35.71
# ...               ...    ...             ...     ...   ...    ...
# 1029    Brad_Thompson    STL  Relief_Pitcher      73   190  25.08
# 1030    Tyler_Johnson    STL  Relief_Pitcher      74   180  25.73
# 1031   Chris_Narveson    STL  Relief_Pitcher      75   205  25.19
# 1032    Randy_Keisler    STL  Relief_Pitcher      75   190  31.01
# 1033      Josh_Kinney    STL  Relief_Pitcher      73   195  27.92
#
# [1034 rows x 6 columns]

# %%
# Leer JSON
df_iris = pd.read_json("/content/iris.json")
df_iris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
# JSON desde url
df_json_url = pd.read_json("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/iris.json")
df_json_url
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
! cat /content/alumnos_calif_jsonArray.json
# Out:
# [
#   {
#     "clave_alu": 11030172,
#     "ap_paterno": "BORBOLLA",
#     "ap_materno": "RAMOS",
#     "nombre": "ARGELIA",
#     "sexo": "F",
#     "ciudad": "QUERETARO",
#     "email": "argi_gogos@email.com",
#     "calificacion": 5
#   },
#   {
#     "clave_alu": 11030173,
#     "ap_paterno": "CASTRO",
#     "ap_materno": "MANCERA",
#     "nombre": "KARLA MARIANA",
#     "sexo": "F",
#     "ciudad": "SANTIAGO DE QUERETARO",
#     "calificacion": 5
#   },
#   {
#     "clave_alu": 11030177,
#     "ap_paterno": "FERRUSCA",
#     "ap_materno": "ANDRADE",
#     "nombre": "OCTAVIO",
#     "sexo": "M",
#     "ciudad": "QUERETARO",
#     "email": "tavoferrus_11@email.com",
#     "calificacion": 5
#   },
#   {
#     "clave_alu": 11030178,
#     "ap_paterno": "GARCIA",
#     "ap_materno": "GOMEZ",
#     "nombre": "RAFAEL",
#     "sexo": "M",
#     "curp": 220140190055288,
#     "ciudad": "QUERETARO",
#     "email": "arobertogarcia@email.net.mx",
#     "calificacion": 5
#   },
#   {
# ...

# %%
df_alumnos = pd.read_json("/content/alumnos_calif_jsonArray.json")
df_alumnos
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3     11030178     GARCIA      GOMEZ         RAFAEL    M
# 4     11030180  GUTIERREZ     FLORES   CARLOS DAVID    M
# ..         ...        ...        ...            ...  ...
# 803   12080001                                       NaN
# 804   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 805   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 806   14080003      MEJIA    JIMENEZ          LUISA  NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN
#
#                     ciudad                        email  calificacion  \
# 0                QUERETARO         argi_gogos@email.com           5.0
# 1    SANTIAGO DE QUERETARO                          NaN           5.0
# ...

# %%
# Lectura de un excel indicando las columnas
colum=['MATRICULA', 'SEDE', 'NOMBRE', 'EDAD', 'SEXO', 'NACIONALIDAD', 'ESTADO_CIVIL', 'MODALIDAD', 'PROM_PSU', 'PROM_NEM', 'SITUACION_ECONOMICA', 'ESTADO', 'CALIFICACION', 'CURSO']
df_carrera = pd.read_excel(
    "/content/BDCarrera.xlsx",
    sheet_name="BdCarrera2022",
    header=None,
    names=colum
    )
df_carrera
# Out:
#      MATRICULA SEDE                             NOMBRE  EDAD SEXO  \
# 0     15797130   SC            INOSTROZA GARNICA KAROL    18    F
# 1     15815731   SC            CORDOVA VIVANCO RODRIGO    18    M
# 2     15819900   SC           ROMERO  OYARZO  CARLOS      17    M
# 3     15848346   SC  GALLARDO  CUEVAS  LORENA CECILIA     20    F
# 4     13539550   SC      JOFRE DONOSO CRISTIAN MARCELO    23    M
# ..         ...  ...                                ...   ...  ...
# 278   15505954   SC        MORALES HERRERA VICTOR HUGO    20    M
# 279   15706371   SC           SANDOVAL PIÑEIRO ARNALDO    19    M
# 280   15873405   SC      MONTES TORRES MISAEL PATRICIO    17    M
# 281   16094619   SC      SILVA FERNANDEZ NELSON JAVIER    18    M
# 282   16114161   SC  VALDES HENRIQUEZ KARINA ALEJANDRA    18    F
#
#     NACIONALIDAD ESTADO_CIVIL  MODALIDAD  PROM_PSU  PROM_NEM  \
# 0       MEXICANA      SOLTERO          1       556       6.0
# ...
